# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/review_data.csv').drop(columns='id')

# %%
df
# Out:
#                                                  comment  \
# 0      Подводя общий итог скажу, что не надо сравнива...
# 1                                                    NaN
# 2      Покупал в подарок жене.  Сложно выбрать женски...
# 3                 О покупке не жалею...мне все нравится.
# 4      Очень хороший тел. Купила его в августе 2014, ...
# ...                                                  ...
# 13782  До него пользовался HTC Legend, когда брал выб...
# 13783  Мне он очень понравился, но мне его поменяют н...
# 13784          Отличный телефон! Берите не пожилеете!!!!
# 13785  Покупкой очень доволен. Брал телефон как мини-...
# 13786  Повелся на новости, что в США Андроид уже наиб...
#
#                                                     cons  \
# 0      -материал задней панели выполнен из пластика, ...
# 1      1.Выступ стекла на 1 мм реально очень плохо......
# 2      - нет сервиса у нас в стране - вопрос с обновл...
# 3      Т.к. в Россию он официально не поставляется то...
# 4                    камера, особенно фронтальная камера
# ...                                                  ...
# 13782  Емкость батареи можно было сделать по больше, ...
# 13783  Мне очень не понравилось, когда 100 раз на ден...
# 13784  У него есть очень большой недостаток, он посто...
# 13785  При частом играния в игры батарея прилично саж...
# 13786  Батареи хватает с трудом на один день. Дизайн ...
#
#                                                     pros  rating
# 0      + смотрится бохато))\n+ быстрая зарядка и дост...       4
# 1      Телефон просто супер!!! очень долго выбирала м...       5
# 2      Яркий интересный внешний вид (который плохо ви...       5
# 3      Большой,все удобно,работает быстро...не тупит ...       5
# 4                             Прочный, удобный, красивый       5
# ...                                                  ...     ...
# 13782  1. Цена качество соответствует. 2. Экран, корп...       5
# 13783  Очень хороший динамик,фотографирует хорошо и в...       5
# 13784  Я вообще выбирал себе телефон между nokia N8 и...       5
# 13785  Хороший дисплей Удобный крепкий корпус HTC sen...       4
# 13786                                                нет       1
#
# [13787 rows x 4 columns]
